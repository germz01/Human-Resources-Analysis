# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
# data set formattato per regole
df = pd.read_csv("../../data/rules/dataset_rules.csv")
#df.head()

# %%
rules = pd.read_csv("../../code/rules/regole_left.csv")
rules.columns
# Out:
# Index([u'Unnamed: 0', u'Consequent', u'Antecedent', u'Supp', u'Conf', u'Lift'], dtype='object')

# %%
# scelgo una regola da testare
rule= rules.loc[664]
rule.Antecedent
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-21-27bef9484eb9> in <module>()
#       1 # scelgo una regola da testare
# ----> 2 rule= rules.loc[664]
#       3 rule.Antecedent
#
# /home/stefano/Py-envs/dm-py2/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /home/stefano/Py-envs/dm-py2/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# /home/stefano/Py-envs/dm-py2/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1440                 raise
# ...

# %% [markdown]
# # calcolo dell'accuracy:
# Per calcolare l'accuracy si deve usare la regola come metodo di classificazione:
#
# Se (Parte antecedente della regola è contenuta in row del dataset) allora predico che il dipendente abbandonerà il lavoro.
#
# Facendolo per tutte le righe del dataset ottengo una colonna di label
# predette, che confrontate con quelle vere mi danno la confusion matrix
# e a seguire l'accuracy/precision/recall

# %%
from ast import literal_eval
literal_eval(rule.Antecedent)
# Out:
# '2_NP'

# %%
from fim import apriori
# ?apriori

# %%
df_best_rules = pd.read_csv("../../data/rules/best_rules_left.csv")
df_best_rules.iloc[0]
# Out:
# Unnamed: 0                                                   664
# Supp                                                        0.09
# Conf                                                        0.96
# Lift                                                        4.05
# Antecedent     {'Satisfaction_Level': 'medium', 'Last_Evaluat...
# Consequent                                         {'Left': 'Y'}
# N_items_Ant                                                    6
# Supp_norm                                                  0.015
# Name: 0, dtype: object
