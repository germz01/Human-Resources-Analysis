# %% [markdown]
# Association rules

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Numero di regole in funzione di supp e conf

# %% [markdown]
# ## numero di regole per supp=20

# %%
supp=20
conf_range=np.arange(50,105,5)
Nrules_supp20 = []
for i,conf in enumerate(conf_range):
    df=pd.read_csv("../../data/rules/rules_supp{}_conf{}.csv".format(supp,conf))
    df=df.query('Lift>1')
    Nrules_supp20.append(df.shape[0])
Nrules_supp20
# Out:
# [122, 99, 85, 81, 69, 69, 61, 53, 37, 31, 8]

# %%
## numero di regole per supp=10

# %%
supp=10
conf_range=np.arange(50,105,5)
Nrules_supp10 = []
for i,conf in enumerate(conf_range):
    df=pd.read_csv("../../data/rules/rules_supp{}_conf{}.csv".format(supp,conf))
    df=df.query('Lift>1')
    Nrules_supp10.append(df.shape[0])
Nrules_supp10
# Out:
# [914, 781, 695, 656, 584, 579, 542, 508, 411, 337, 63]

# %%
## numero di regole per supp=5

# %%
supp=5
conf_range=np.arange(50,105,5)
Nrules_supp5 = []
for i,conf in enumerate(conf_range):
    df=pd.read_csv("../../data/rules/rules_supp{}_conf{}.csv".format(supp,conf))
    df=df.query('Lift>1')
    Nrules_supp5.append(df.shape[0])
Nrules_supp5
# Out:
# [4457, 3984, 3594, 3236, 3029, 2955, 2819, 2572, 2261, 1881, 261]

# %% [markdown]
# # Grafico numero di regole (Lift>1)

# %%
###########################################################
SMALL_SIZE = 15
MEDIUM_SIZE = 20
BIGGER_SIZE = 30
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y label
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('axes', axisbelow=True)
###########################################################

fig = plt.figure(figsize=(13,5))
ax = fig.add_subplot(111)
plt.plot(conf_range,Nrules_supp20, label='MinSupp = 20%', linewidth=5)
plt.plot(conf_range,Nrules_supp10, label='MinSupp = 10%', linewidth=5)
plt.plot(conf_range,Nrules_supp5, label='MinSupp =  5%', linewidth=5)
plt.scatter(conf_range,Nrules_supp20,s=100)
plt.scatter(conf_range,Nrules_supp10,s=100)
plt.scatter(conf_range,Nrules_supp5,s=100)

plt.legend()

ax.set_yscale('log')

plt.xlabel('Minimum Confidence (%)')
plt.ylabel('Number of rules (logscale)')

plt.ylim(1,10000)

plt.grid(b=True, which='major', color='0', linestyle='--')
plt.grid(b=True, which='minor', color='0', linestyle=':')

plt.title("Number of association rules with Lift>1")
plt.tight_layout()

plt.savefig("../../images/rules/andamentonumero.pdf")

# %%
###########################################################

SMALL_SIZE = 15
MEDIUM_SIZE = 20
BIGGER_SIZE = 30

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y label
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('axes', axisbelow=True)
###########################################################

# %%
# regole generali

# %%
df = pd.read_csv("../../data/rules/rules_supp20_conf50.csv")
df.shape
#df_filtered = df.query('Supp>0.2') # perchè non è maggiore di 20???
#df_filtered = df_filtered.query('Lift>1')
df_filtered=df
df_filtered.describe()
# Out:
#              Supp        Conf        Lift
# count  259.000000  259.000000  259.000000
# mean     0.289807    0.826911    1.112896
# std      0.102271    0.154743    0.271226
# min      0.200000    0.500000    0.880000
# 25%      0.220000    0.730000    0.990000
# 50%      0.260000    0.850000    1.000000
# 75%      0.320000    0.980000    1.125000
# max      0.840000    1.000000    2.100000

# %%
fig = plt.figure(figsize=(10,10))
plt.grid()
size= 5000*(df_filtered.Supp)**(2)
palette='Accent'
palette='viridis'
plt.scatter(x='Conf', y='Lift',data=df_filtered,s=size, alpha=0.7 ,c='Supp',cmap =plt.cm.get_cmap(palette,3))
cb = plt.colorbar(orientation='horizontal',extend='max',ticks=np.arange(0.20,0.70,0.10))
cb.set_label('Support')

#plt.colorbar(extend='both')
plt.clim(0.2,0.5)
plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.title("Interest of Association rules, for Min Supp = 20%")
#plt.legend()
plt.tight_layout()

plt.savefig("../../images/rules/rules_supp20.pdf")

# %%
df_interesting = df_filtered.query(" Lift >1.7")
df_interesting = df_interesting.sort_values(by=['Conf','Consequent','Supp'],ascending=False)

import sys
stdout= sys.stdout
sys.stdout = open('../../data/rules/rules_supp20.txt','w')
print( df_interesting.to_latex(index=False) )
#print( df[100:300].to_latex(index=False) )
sys.stdout=stdout

#df.query(" Conf<0.7 & Lift >1.8")[0:1].to_latex(index_names=False) 

##?df.to_latex()
df_interesting
# Out:
#       Consequent                              Antecedent  Supp  Conf  Lift
# 78       high_SL                       ('very good_LE',)  0.32  1.00  2.09
# 76       high_SL                 ('very good_LE', 'N_P')  0.31  1.00  2.09
# 63       high_SL          ('very good_LE', 'N_L', 'N_P')  0.27  1.00  2.09
# 66       high_SL                 ('very good_LE', 'N_L')  0.27  1.00  2.09
# 70       high_SL         ('very good_LE', 'N_WA', 'N_P')  0.27  1.00  2.09
# 73       high_SL                ('very good_LE', 'N_WA')  0.27  1.00  2.09
# 59       high_SL         ('very good_LE', 'N_L', 'N_WA')  0.23  1.00  2.09
# 55       high_SL  ('very good_LE', 'N_L', 'N_WA', 'N_P')  0.22  1.00  2.09
# 71  very good_LE              ('high_SL', 'N_WA', 'N_P')  0.27  0.68  2.10
# 74  very good_LE                     ('high_SL', 'N_WA')  0.27  0.68  2.10
# 79  very good_LE                            ('high_SL',)  0.32  0.67  2.09
# 77  very good_LE                      ('high_SL', 'N_P')  0.31  0.67  2.09
# 64  very good_LE               ('high_SL', 'N_L', 'N_P')  0.27  0.66  2.05
# 67  very good_LE                      ('high_SL', 'N_L')  0.27  0.66  2.05
# 60  very good_LE              ('high_SL', 'N_L', 'N_WA')  0.23  0.66  2.06
# 56  very good_LE       ('high_SL', 'N_L', 'N_WA', 'N_P')  0.22  0.66  2.05

# %%
# Regole per supp=5

# %%
df = pd.read_csv("../../data/rules/rules_supp5_conf50.csv")
df.shape
#df_filtered = df.query('Supp>0.2') # perchè non è maggiore di 20???
#df_filtered = df_filtered.query('Lift>1')
df_filtered=df
df_filtered.describe()
# Out:
#               Supp         Conf         Lift
# count  5862.000000  5862.000000  5862.000000
# mean      0.088763     0.835553     1.658640
# std       0.056477     0.164999     1.118199
# min       0.050000     0.500000     0.660000
# 25%       0.060000     0.690000     1.010000
# 50%       0.070000     0.880000     1.140000
# 75%       0.100000     0.980000     2.030000
# max       0.840000     1.000000     7.170000

# %%
plt.close()
fig = plt.figure(figsize=(10,10))
plt.grid()
size= 2000*(df_filtered.Supp)**(1)
plt.scatter(x='Lift', y='Conf',data=df_filtered,s=size, alpha=0.7 ,c='Supp',cmap =plt.cm.get_cmap('Accent',3))

plt.clim(0.05,0.2)
cb = plt.colorbar(extend='max',orientation='horizontal',ticks=np.arange(0.05,0.70,0.05))
cb.set_label('Support')


plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.title("Interest of Association rules, for Min Supp = 5%")
#plt.legend()
plt.tight_layout()

plt.savefig("../../images/rules/rules_supp5.pdf")

# %%
import seaborn as sns
sns.set_context("poster")
df_filtered.head()
# Out:
#   Consequent       Antecedent  Supp  Conf  Lift
# 0        N_P         ('7_D',)  0.05  0.98  1.00
# 1        N_P         ('6_D',)  0.05  0.97  0.99
# 2        N_P         ('5_D',)  0.05  0.95  0.97
# 3        N_P  ('4_D', 'N_WA')  0.05  1.00  1.02
# 4       N_WA   ('4_D', 'N_P')  0.05  0.85  1.00

# %%
df_plot = df_filtered.query("Lift>0.2 and Conf>0.7 and Supp>0.1").sort_values(by=["Lift","Consequent"],ascending=False)


Cons_label=[]

for i in range(df_plot.shape[0]):
    Cons_label.append(dict2str(item2dict(df_plot.Consequent.iloc[i])))

df_plot['Cons_label']=Cons_label
df_plot.head()
# Out:
#           Consequent                               Antecedent  Supp  Conf  \
# 264  insufficient_LE                ('low_SL', 'N_WA', 'N_P')  0.12   1.0
# 267  insufficient_LE                       ('low_SL', 'N_WA')  0.12   1.0
# 270  insufficient_LE                        ('low_SL', 'N_P')  0.14   1.0
# 272  insufficient_LE                              ('low_SL',)  0.14   1.0
# 501        medium_SL  ('sufficient_LE', 'N_L', 'N_WA', 'N_P')  0.11   1.0
#
#      Lift                    Cons_label
# 264  3.86  Last_Evaluation:insufficient
# 267  3.86  Last_Evaluation:insufficient
# 270  3.86  Last_Evaluation:insufficient
# 272  3.86  Last_Evaluation:insufficient
# 501  2.65     Satisfaction_Level:medium

# %%
sns.set_style('whitegrid')

size= 2000*(df_filtered.Supp)**(1)

sns.set_palette("Paired")

left_plot = sns.lmplot(x='Lift',y='Conf',data=df_plot,hue='Cons_label',fit_reg=True,
                       aspect=(20/10),
                       legend_out=True,palette='Paired')
plt.ylim(0.45,1.05)
plt.ylim(0.8,1.05)
#plt.xlim(0.5,8.1)

plt.axvline(1,color='r',linestyle="--")

sns.set_palette("Paired")
plt.title("Association rules for MinSupp = 5%")


left_plot.savefig("../../images/rules/left_scatter.pdf")
#plt.scatter(x='Conf', y='Lift',data=df_filtered,s=size, alpha=0.7 ,c='Consequent',cmap =plt.cm.get_cmap('Accent',3))

# %%
# ?sns.lmplot()

# %%
df_plot.query("Conf>0.99").describe()
df_plot.head(100)
# Out:
#            Consequent                                  Antecedent  Supp  Conf  \
# 264   insufficient_LE                   ('low_SL', 'N_WA', 'N_P')  0.12  1.00
# 267   insufficient_LE                          ('low_SL', 'N_WA')  0.12  1.00
# 270   insufficient_LE                           ('low_SL', 'N_P')  0.14  1.00
# 272   insufficient_LE                                 ('low_SL',)  0.14  1.00
# 501         medium_SL     ('sufficient_LE', 'N_L', 'N_WA', 'N_P')  0.11  1.00
# 504         medium_SL            ('sufficient_LE', 'N_L', 'N_WA')  0.11  1.00
# 507         medium_SL             ('sufficient_LE', 'N_L', 'N_P')  0.13  1.00
# 509         medium_SL                    ('sufficient_LE', 'N_L')  0.13  1.00
# 512         medium_SL            ('sufficient_LE', 'N_WA', 'N_P')  0.12  1.00
# 514         medium_SL                   ('sufficient_LE', 'N_WA')  0.13  1.00
# 516         medium_SL                    ('sufficient_LE', 'N_P')  0.15  1.00
# 517         medium_SL                          ('sufficient_LE',)  0.15  1.00
# 1650        medium_SL        ('2_NP', '3_T', 'standard_H', 'N_P')  0.11  0.95
# 1654        medium_SL               ('2_NP', '3_T', 'standard_H')  0.11  0.95
# 1663        medium_SL                     ('2_NP', '3_T', 'N_WA')  0.11  0.92
# 1667        medium_SL                      ('2_NP', '3_T', 'N_P')  0.11  0.91
# 1670        medium_SL                             ('2_NP', '3_T')  0.11  0.91
# 1707        medium_SL       ('2_NP', 'standard_H', 'N_WA', 'N_P')  0.11  0.91
# 1711        medium_SL              ('2_NP', 'standard_H', 'N_WA')  0.11  0.91
# 1715        medium_SL               ('2_NP', 'standard_H', 'N_P')  0.12  0.90
# 1717        medium_SL                      ('2_NP', 'standard_H')  0.12  0.90
# 1720        medium_SL                     ('2_NP', 'N_WA', 'N_P')  0.12  0.84
# 1722        medium_SL                            ('2_NP', 'N_WA')  0.12  0.84
# 1724        medium_SL                             ('2_NP', 'N_P')  0.13  0.82
# 1725        medium_SL                                   ('2_NP',)  0.13  0.82
# 1649              3_T  ('2_NP', 'medium_SL', 'standard_H', 'N_P')  0.11  0.90
# 4209          high_SL             ('4_NP', 'very good_LE', 'N_P')  0.12  1.00
# 4211          high_SL                    ('4_NP', 'very good_LE')  0.12  1.00
# 4626          high_SL      ('very good_LE', '3_T', 'N_L', 'N_WA')  0.11  1.00
# 4630          high_SL       ('very good_LE', '3_T', 'N_L', 'N_P')  0.12  1.00
# ...               ...                                         ...   ...   ...
# 1653              3_T         ('2_NP', 'medium_SL', 'standard_H')  0.11  0.90
# 1662              3_T               ('2_NP', 'medium_SL', 'N_WA')  0.11  0.87
# 1666              3_T                ('2_NP', 'medium_SL', 'N_P')  0.11  0.86
# 1669              3_T                       ('2_NP', 'medium_SL')  0.11  0.86
# 1759              3_T       ('2_NP', 'standard_H', 'N_WA', 'N_P')  0.11  0.86
# 1762              3_T              ('2_NP', 'standard_H', 'N_WA')  0.11  0.85
# 1765              3_T               ('2_NP', 'standard_H', 'N_P')  0.11  0.85
# 1767              3_T                      ('2_NP', 'standard_H')  0.11  0.84
# 1648       standard_H         ('2_NP', 'medium_SL', '3_T', 'N_P')  0.11  0.97
# 1652       standard_H                ('2_NP', 'medium_SL', '3_T')  0.11  0.97
# 1706       standard_H        ('2_NP', 'medium_SL', 'N_WA', 'N_P')  0.11  0.94
# 1710       standard_H               ('2_NP', 'medium_SL', 'N_WA')  0.11  0.94
# 1758       standard_H              ('2_NP', '3_T', 'N_WA', 'N_P')  0.11  0.93
# 1761       standard_H                     ('2_NP', '3_T', 'N_WA')  0.11  0.93
# 1714       standard_H                ('2_NP', 'medium_SL', 'N_P')  0.12  0.93
# 1716       standard_H                       ('2_NP', 'medium_SL')  0.12  0.93
# 1764       standard_H                      ('2_NP', '3_T', 'N_P')  0.11  0.93
# 1766       standard_H                             ('2_NP', '3_T')  0.11  0.93
# 3079       standard_H     ('insufficient_LE', 'medium_SL', 'N_P')  0.11  0.92
# 3081       standard_H            ('insufficient_LE', 'medium_SL')  0.11  0.92
# 1805       standard_H                     ('2_NP', 'N_WA', 'N_P')  0.12  0.87
# 1807       standard_H                            ('2_NP', 'N_WA')  0.13  0.87
# 1809       standard_H                             ('2_NP', 'N_P')  0.13  0.85
# 1810       standard_H                                   ('2_NP',)  0.14  0.85
# 3642              N_L                      ('3_NP', '3_T', 'N_P')  0.12  0.99
# 3643              N_L                             ('3_NP', '3_T')  0.12  0.99
# 4629              N_L   ('very good_LE', '3_T', 'high_SL', 'N_P')  0.12  1.00
# 4690              N_L              ('very good_LE', '3_T', 'N_P')  0.12  1.00
# 2326              N_L                   ('2_T', 'high_SL', 'N_P')  0.12  0.99
# 2328              N_L                          ('2_T', 'high_SL')  0.12  0.99
#
#       Lift                     Cons_label
# 264   3.86   Last_Evaluation:insufficient
# 267   3.86   Last_Evaluation:insufficient
# 270   3.86   Last_Evaluation:insufficient
# 272   3.86   Last_Evaluation:insufficient
# 501   2.65      Satisfaction_Level:medium
# 504   2.65      Satisfaction_Level:medium
# 507   2.65      Satisfaction_Level:medium
# 509   2.65      Satisfaction_Level:medium
# 512   2.65      Satisfaction_Level:medium
# 514   2.65      Satisfaction_Level:medium
# 516   2.65      Satisfaction_Level:medium
# 517   2.65      Satisfaction_Level:medium
# 1650  2.52      Satisfaction_Level:medium
# 1654  2.52      Satisfaction_Level:medium
# 1663  2.43      Satisfaction_Level:medium
# 1667  2.41      Satisfaction_Level:medium
# 1670  2.41      Satisfaction_Level:medium
# 1707  2.40      Satisfaction_Level:medium
# 1711  2.39      Satisfaction_Level:medium
# 1715  2.37      Satisfaction_Level:medium
# 1717  2.37      Satisfaction_Level:medium
# 1720  2.22      Satisfaction_Level:medium
# 1722  2.22      Satisfaction_Level:medium
# 1724  2.17      Satisfaction_Level:medium
# 1725  2.17      Satisfaction_Level:medium
# 1649  2.10           Time_Spend_Company:3
# 4209  2.09        Satisfaction_Level:high
# 4211  2.09        Satisfaction_Level:high
# 4626  2.09        Satisfaction_Level:high
# 4630  2.09        Satisfaction_Level:high
# ...    ...                            ...
# 1653  2.09           Time_Spend_Company:3
# 1662  2.03           Time_Spend_Company:3
# 1666  2.01           Time_Spend_Company:3
# 1669  2.00           Time_Spend_Company:3
# 1759  2.00           Time_Spend_Company:3
# 1762  1.99           Time_Spend_Company:3
# 1765  1.97           Time_Spend_Company:3
# 1767  1.96           Time_Spend_Company:3
# 1648  1.95  Average_Montly_Hours:standard
# 1652  1.95  Average_Montly_Hours:standard
# 1706  1.89  Average_Montly_Hours:standard
# 1710  1.89  Average_Montly_Hours:standard
# 1758  1.88  Average_Montly_Hours:standard
# 1761  1.88  Average_Montly_Hours:standard
# 1714  1.87  Average_Montly_Hours:standard
# 1716  1.87  Average_Montly_Hours:standard
# 1764  1.86  Average_Montly_Hours:standard
# 1766  1.86  Average_Montly_Hours:standard
# 3079  1.84  Average_Montly_Hours:standard
# 3081  1.84  Average_Montly_Hours:standard
# 1805  1.75  Average_Montly_Hours:standard
# 1807  1.75  Average_Montly_Hours:standard
# 1809  1.72  Average_Montly_Hours:standard
# 1810  1.71  Average_Montly_Hours:standard
# 3642  1.31                         Left:N
# 3643  1.31                         Left:N
# 4629  1.31                         Left:N
# 4690  1.31                         Left:N
# 2326  1.30                         Left:N
# 2328  1.30                         Left:N
#
# [100 rows x 6 columns]

# %%
df_interesting = df_filtered.query(" Lift >5")
df_interesting = df_interesting.query(" Conf >0.95")
df_interesting = df_interesting.sort_values(by=['Consequent','Lift','Supp'],ascending=False)
df_interesting
#((df_interesting.Antecedent[665]))
# Out:
#      Consequent                                         Antecedent  Supp  \
# 122      low_SL           ('4_T', 'Y_L', 'insufficient_LE', 'N_P')  0.05
# 126      low_SL                  ('4_T', 'Y_L', 'insufficient_LE')  0.05
# 112      low_SL   ('4_T', 'Y_L', 'insufficient_LE', 'N_WA', 'N_P')  0.05
# 117      low_SL          ('4_T', 'Y_L', 'insufficient_LE', 'N_WA')  0.05
# 151      low_SL          ('4_T', 'insufficient_LE', 'intensive_H')  0.05
# 147      low_SL   ('4_T', 'insufficient_LE', 'intensive_H', 'N_P')  0.05
# 187      low_SL   ('Y_L', 'insufficient_LE', 'intensive_H', 'N_P')  0.05
# 191      low_SL          ('Y_L', 'insufficient_LE', 'intensive_H')  0.05
# 665        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.09
# 671        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.09
# 651        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.08
# 658        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.08
# 592        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.05
# 600        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.05
# 608        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.05
# 615        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.05
# 1038       2_NP   ('Y_L', 'medium_SL', '3_T', 'standard_H', 'N_P')  0.10
# 1043       2_NP          ('Y_L', 'medium_SL', '3_T', 'standard_H')  0.10
# 1026       2_NP  ('Y_L', 'medium_SL', '3_T', 'standard_H', 'N_W...  0.10
# 1032       2_NP  ('Y_L', 'medium_SL', '3_T', 'standard_H', 'N_WA')  0.10
# 690        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.09
# 695        2_NP     ('Y_L', 'insufficient_LE', 'medium_SL', '3_T')  0.09
# 678        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.08
# 684        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.08
# 975        2_NP  ('Y_L', 'medium_SL', '3_T', '0_S', 'standard_H...  0.06
# 982        2_NP  ('Y_L', 'medium_SL', '3_T', '0_S', 'standard_H...  0.06
# 989        2_NP  ('Y_L', 'medium_SL', '3_T', '0_S', 'standard_H...  0.06
# 995        2_NP   ('Y_L', 'medium_SL', '3_T', '0_S', 'standard_H')  0.06
# 623        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.05
# 630        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.05
# ...         ...                                                ...   ...
# 1123       2_NP          ('Y_L', 'medium_SL', 'standard_H', 'N_P')  0.10
# 1127       2_NP                 ('Y_L', 'medium_SL', 'standard_H')  0.10
# 883        2_NP           ('Y_L', 'insufficient_LE', '3_T', 'N_P')  0.09
# 887        2_NP                  ('Y_L', 'insufficient_LE', '3_T')  0.09
# 873        2_NP   ('Y_L', 'insufficient_LE', '3_T', 'N_WA', 'N_P')  0.08
# 878        2_NP          ('Y_L', 'insufficient_LE', '3_T', 'N_WA')  0.08
# 787        2_NP     ('Y_L', 'insufficient_LE', 'medium_SL', 'N_P')  0.09
# 791        2_NP            ('Y_L', 'insufficient_LE', 'medium_SL')  0.09
# 777        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', 'N_WA'...  0.08
# 782        2_NP    ('Y_L', 'insufficient_LE', 'medium_SL', 'N_WA')  0.08
# 826        2_NP  ('Y_L', 'insufficient_LE', '3_T', '0_S', 'N_WA...  0.05
# 832        2_NP   ('Y_L', 'insufficient_LE', '3_T', '0_S', 'N_WA')  0.05
# 838        2_NP    ('Y_L', 'insufficient_LE', '3_T', '0_S', 'N_P')  0.05
# 843        2_NP           ('Y_L', 'insufficient_LE', '3_T', '0_S')  0.05
# 1220       2_NP                              ('Y_L', '3_T', 'N_P')  0.10
# 1287       2_NP  ('insufficient_LE', 'medium_SL', '3_T', '0_S',...  0.05
# 1294       2_NP  ('insufficient_LE', 'medium_SL', '3_T', '0_S',...  0.05
# 1212       2_NP                      ('Y_L', '3_T', 'N_WA', 'N_P')  0.10
# 1223       2_NP                                     ('Y_L', '3_T')  0.10
# 1216       2_NP                             ('Y_L', '3_T', 'N_WA')  0.10
# 937        2_NP  ('Y_L', 'insufficient_LE', 'standard_H', 'N_WA...  0.08
# 942        2_NP   ('Y_L', 'insufficient_LE', 'standard_H', 'N_WA')  0.08
# 947        2_NP    ('Y_L', 'insufficient_LE', 'standard_H', 'N_P')  0.09
# 951        2_NP           ('Y_L', 'insufficient_LE', 'standard_H')  0.09
# 1183       2_NP                       ('Y_L', '3_T', '0_S', 'N_P')  0.06
# 900        2_NP  ('Y_L', 'insufficient_LE', '0_S', 'standard_H'...  0.05
# 1173       2_NP               ('Y_L', '3_T', '0_S', 'N_WA', 'N_P')  0.06
# 894        2_NP  ('Y_L', 'insufficient_LE', '0_S', 'standard_H'...  0.05
# 1301       2_NP  ('insufficient_LE', 'medium_SL', '3_T', '0_S',...  0.05
# 1307       2_NP  ('insufficient_LE', 'medium_SL', '3_T', '0_S',...  0.05
#
#       Conf  Lift
# 122   0.98  7.17
# 126   0.98  7.17
# 112   0.98  7.16
# 117   0.98  7.16
# 151   0.97  7.11
# 147   0.97  7.10
# 187   0.97  7.10
# 191   0.97  7.10
# 665   1.00  6.28
# 671   1.00  6.28
# 651   1.00  6.28
# 658   1.00  6.28
# 592   1.00  6.27
# 600   1.00  6.27
# 608   1.00  6.27
# 615   1.00  6.27
# 1038  1.00  6.26
# 1043  1.00  6.26
# 1026  1.00  6.25
# 1032  1.00  6.25
# 690   0.99  6.25
# 695   0.99  6.25
# 678   0.99  6.25
# 684   0.99  6.25
# 975   1.00  6.25
# 982   1.00  6.25
# 989   1.00  6.25
# 995   1.00  6.25
# 623   0.99  6.25
# 630   0.99  6.25
# ...    ...   ...
# 1123  0.98  6.14
# 1127  0.98  6.14
# 883   0.98  6.14
# 887   0.98  6.14
# 873   0.98  6.13
# 878   0.98  6.13
# 787   0.97  6.12
# 791   0.97  6.12
# 777   0.97  6.11
# 782   0.97  6.11
# 826   0.97  6.10
# 832   0.97  6.10
# 838   0.97  6.10
# 843   0.97  6.10
# 1220  0.96  6.06
# 1287  0.97  6.06
# 1294  0.97  6.06
# 1212  0.96  6.05
# 1223  0.96  6.05
# 1216  0.96  6.04
# 937   0.96  6.04
# 942   0.96  6.04
# 947   0.96  6.03
# 951   0.96  6.03
# 1183  0.96  6.01
# 900   0.96  6.01
# 1173  0.96  6.00
# 894   0.96  6.00
# 1301  0.96  6.00
# 1307  0.96  6.00
#
# [104 rows x 5 columns]

# %%
import sys
stdout= sys.stdout
sys.stdout = open('../../data/rules/rules_supp5.txt','w')
print( df_interesting.to_latex(index=False) )
sys.stdout=stdout

##?df.to_latex()

# %%
# Analisi regole Per LEFT

# %%
df_left = df_filtered.query(" Consequent=='Y_L'")
df_left = df_left.query("Conf >0.5 and Lift>2")
df_left = df_left.sort_values(by=['Consequent','Conf','Supp'],ascending=False)
df_left.describe()
df_left.head(100)
#df_left.Antecedent.iloc[1]
# Out:
#      Consequent                                         Antecedent  Supp  \
# 591         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 599         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 607         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 614         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 622         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 629         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 650         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.08
# 636         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 642         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 664         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.09
# 670         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.09
# 689         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.09
# 694         Y_L    ('2_NP', 'insufficient_LE', 'medium_SL', '3_T')  0.09
# 657         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.08
# 677         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.08
# 683         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.08
# 702         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '0_S'...  0.05
# 709         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '0_S'...  0.05
# 798         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'sta...  0.05
# 805         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'sta...  0.05
# 812         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'sta...  0.05
# 818         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'sta...  0.05
# 825         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'N_W...  0.05
# 831         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'N_WA')  0.05
# 861         Y_L  ('2_NP', 'insufficient_LE', '3_T', 'standard_H...  0.09
# 866         Y_L   ('2_NP', 'insufficient_LE', '3_T', 'standard_H')  0.09
# 849         Y_L  ('2_NP', 'insufficient_LE', '3_T', 'standard_H...  0.08
# 855         Y_L  ('2_NP', 'insufficient_LE', '3_T', 'standard_H...  0.08
# 872         Y_L  ('2_NP', 'insufficient_LE', '3_T', 'N_WA', 'N_P')  0.08
# 974         Y_L  ('2_NP', 'medium_SL', '3_T', '0_S', 'standard_...  0.06
# ...         ...                                                ...   ...
# 921         Y_L         ('2_NP', 'insufficient_LE', '0_S', 'N_WA')  0.05
# 2448        Y_L  ('insufficient_LE', 'medium_SL', '3_T', '0_S',...  0.05
# 2453        Y_L     ('insufficient_LE', 'medium_SL', '3_T', '0_S')  0.05
# 1048        Y_L        ('2_NP', 'medium_SL', '3_T', 'N_WA', 'N_P')  0.10
# 1053        Y_L               ('2_NP', 'medium_SL', '3_T', 'N_WA')  0.10
# 790         Y_L           ('2_NP', 'insufficient_LE', 'medium_SL')  0.09
# 936         Y_L  ('2_NP', 'insufficient_LE', 'standard_H', 'N_W...  0.08
# 941         Y_L  ('2_NP', 'insufficient_LE', 'standard_H', 'N_WA')  0.08
# 2460        Y_L  ('insufficient_LE', 'medium_SL', '3_T', 'stand...  0.08
# 1149        Y_L  ('2_NP', '3_T', '0_S', 'standard_H', 'N_WA', '...  0.06
# 1155        Y_L       ('2_NP', '3_T', '0_S', 'standard_H', 'N_WA')  0.06
# 1166        Y_L               ('2_NP', '3_T', '0_S', 'standard_H')  0.06
# 1058        Y_L                ('2_NP', 'medium_SL', '3_T', 'N_P')  0.10
# 1062        Y_L                       ('2_NP', 'medium_SL', '3_T')  0.10
# 946         Y_L   ('2_NP', 'insufficient_LE', 'standard_H', 'N_P')  0.09
# 950         Y_L          ('2_NP', 'insufficient_LE', 'standard_H')  0.09
# 2472        Y_L  ('insufficient_LE', 'medium_SL', '3_T', 'stand...  0.09
# 2466        Y_L  ('insufficient_LE', 'medium_SL', '3_T', 'stand...  0.08
# 1161        Y_L        ('2_NP', '3_T', '0_S', 'standard_H', 'N_P')  0.06
# 926         Y_L          ('2_NP', 'insufficient_LE', '0_S', 'N_P')  0.05
# 930         Y_L                 ('2_NP', 'insufficient_LE', '0_S')  0.05
# 1192        Y_L       ('2_NP', '3_T', 'standard_H', 'N_WA', 'N_P')  0.10
# 1197        Y_L              ('2_NP', '3_T', 'standard_H', 'N_WA')  0.10
# 2477        Y_L  ('insufficient_LE', 'medium_SL', '3_T', 'stand...  0.09
# 2483        Y_L  ('insufficient_LE', 'medium_SL', '3_T', 'N_WA'...  0.08
# 2488        Y_L    ('insufficient_LE', 'medium_SL', '3_T', 'N_WA')  0.08
# 1069        Y_L  ('2_NP', 'medium_SL', '0_S', 'standard_H', 'N_...  0.06
# 1075        Y_L  ('2_NP', 'medium_SL', '0_S', 'standard_H', 'N_...  0.06
# 2584        Y_L  ('insufficient_LE', '3_T', '0_S', 'standard_H'...  0.05
# 2590        Y_L  ('insufficient_LE', '3_T', '0_S', 'standard_H'...  0.05
#
#       Conf  Lift
# 591   0.98  4.10
# 599   0.98  4.10
# 607   0.98  4.10
# 614   0.98  4.10
# 622   0.98  4.10
# 629   0.98  4.10
# 650   0.97  4.06
# 636   0.97  4.09
# 642   0.97  4.09
# 664   0.96  4.05
# 670   0.96  4.04
# 689   0.96  4.02
# 694   0.96  4.02
# 657   0.96  4.05
# 677   0.96  4.05
# 683   0.96  4.05
# 702   0.96  4.02
# 709   0.96  4.02
# 798   0.96  4.05
# 805   0.96  4.05
# 812   0.96  4.04
# 818   0.96  4.04
# 825   0.96  4.02
# 831   0.96  4.02
# 861   0.95  3.99
# 866   0.95  3.98
# 849   0.95  4.00
# 855   0.95  4.00
# 872   0.95  3.97
# 974   0.95  3.97
# ...    ...   ...
# 921   0.92  3.84
# 2448  0.92  3.86
# 2453  0.92  3.86
# 1048  0.91  3.83
# 1053  0.91  3.83
# 790   0.91  3.84
# 936   0.91  3.81
# 941   0.91  3.80
# 2460  0.91  3.82
# 1149  0.91  3.83
# 1155  0.91  3.84
# 1166  0.91  3.80
# 1058  0.90  3.78
# 1062  0.90  3.78
# 946   0.90  3.78
# 950   0.90  3.77
# 2472  0.90  3.77
# 2466  0.90  3.80
# 1161  0.90  3.80
# 926   0.90  3.78
# 930   0.90  3.78
# 1192  0.89  3.75
# 1197  0.89  3.75
# 2477  0.89  3.75
# 2483  0.89  3.76
# 2488  0.89  3.74
# 1069  0.89  3.75
# 1075  0.89  3.75
# 2584  0.89  3.75
# 2590  0.89  3.75
#
# [100 rows x 5 columns]

# %%
df_left.Lift/df_left.Conf
# Out:
# 591     4.183673
# 599     4.183673
# 607     4.183673
# 614     4.183673
# 622     4.183673
# 629     4.183673
# 636     4.216495
# 642     4.216495
# 650     4.185567
# 664     4.218750
# 657     4.218750
# 677     4.218750
# 683     4.218750
# 798     4.218750
# 805     4.218750
# 670     4.208333
# 812     4.208333
# 818     4.208333
# 689     4.187500
# 694     4.187500
# 702     4.187500
# 709     4.187500
# 825     4.187500
# 831     4.187500
# 716     4.221053
# 722     4.221053
# 849     4.210526
# 855     4.210526
# 837     4.210526
# 842     4.210526
#           ...
# 2739    4.183333
# 2726    4.183333
# 186     4.183333
# 204     4.183333
# 2661    4.237288
# 2741    4.220339
# 2729    4.220339
# 190     4.220339
# 206     4.220339
# 2664    4.186441
# 2775    4.169492
# 2780    4.169492
# 2708    4.169492
# 2710    4.224138
# 77      4.210526
# 78      4.175439
# 2667    4.214286
# 2669    4.160714
# 2785    4.200000
# 2789    4.200000
# 2712    4.200000
# 2713    4.181818
# 2829    4.226415
# 2834    4.207547
# 195     4.173077
# 209     4.173077
# 198     4.235294
# 211     4.235294
# 2814    4.196078
# 2818    4.176471
# Length: 242, dtype: float64

# %%
import sys
stdout= sys.stdout
sys.stdout = open('../../data/rules/rules_left.txt','w')
print( df_left.to_latex(index=False) )
sys.stdout=stdout

##?df.to_latex()

# %%
df_left.head()
# Out:
#     Consequent                                         Antecedent  Supp  Conf  \
# 591        Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05  0.98
# 599        Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05  0.98
# 607        Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05  0.98
# 614        Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05  0.98
# 622        Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05  0.98
#
#      Lift
# 591   4.1
# 599   4.1
# 607   4.1
# 614   4.1
# 622   4.1

# %% [markdown]
# # Conversione DataFrame

# %%
variables = ['Time_Spend_Company',
            'Department',
            'Number_Projects',
            'Promotion_Last_5_Years',
            'Left',
            'Average_Montly_Hours',
            'Work_Accident',
            'Last_Evaluation',
            'Salary',
            'Satisfaction_Level']

other_columns = ['Antecedent','Consequent','Supp','Conf','Lift']

from copy import copy
columns = copy(variables)

for col in other_columns:
    columns.append(col)

# %%
var_dict = {
    'T':'Time_Spend_Company',
    'D':'Department',
    'NP':'Number_Projects',
    'P':'Promotion_Last_5_Years',
    'L':'Left',
    'H':'Average_Montly_Hours',
    'WA':'Work_Accident',
    'LE':'Last_Evaluation',
    'S':'Salary',
    'SL':'Satisfaction_Level'
}

def item2dict(item):
    ## splitto la stringa
    item_split = item.split('_')
    # definisco la lista variabile,valore
    item_list = {var_dict[item_split[1]] : item_split[0]}
    return item_list



item=df.Consequent[10]
item2dict(item)
# Out:
# {'Satisfaction_Level': 'low'}

# %%
item_dict = item2dict(item)
def dict2str(item_dict):
    for key in item_dict:
        item_str= "{}:{}".format(key,item_dict[key])
    return item_str

dict2str(item_dict)
# Out:
# 'Satisfaction_Level:low'

# %%
# funzione che converte la parte antecedent in lista di dizionari

from ast import literal_eval

def antecedent2list(antecedent_str):
    antecedent_tuple = literal_eval(antecedent_str)

    out_list = []
    for item in antecedent_tuple:
        out_list.append(item2dict(item=item))
        
    return out_list


def antecedent2dict(antecedent_str):
    """converte la singola parte antecedente 
    in dizionario """

    antecedent_tuple = literal_eval(antecedent_str)

    out_list = {}
    for item in antecedent_tuple:
        out_list.update(item2dict(item=item))
        
    return out_list


#esempio
out= antecedent2list(df.Antecedent[45])
out2 = antecedent2dict(df.Antecedent[45])

df.Antecedent[45]

out2.keys()
out2
# Out:
# {'Department': '3', 'Left': 'N'}

# %%
def df2df_list(df):
    """funzione che converte 
    le stringhe relative alle regole in 
    liste di dizionari """

    df_new = df.copy()

    df_new = df_new.drop(['Antecedent','Consequent'],axis=1)

    Antecedent=[]
    for i,item in enumerate(df.Antecedent):
        Antecedent.append(antecedent2list(item))

    df_new=df_new.assign(Antecedent=Antecedent)

    Consequent=[]
    for i,item in enumerate(df.Consequent):
        Consequent.append(item2dict(item))

    df_new=df_new.assign(Consequent=Consequent)
        
    return df_new        


def df2df_dict(df):
    """funzione che converte 
    le stringhe relative alle regole in 
    liste di dizionari """

    df_new = df.copy()

    df_new = df_new.drop(['Antecedent','Consequent'],axis=1)

    Antecedent=[]
    for i,item in enumerate(df.Antecedent):
        Antecedent.append(antecedent2dict(item))

    df_new=df_new.assign(Antecedent=Antecedent)

    Consequent=[]
    for i,item in enumerate(df.Consequent):
        Consequent.append(item2dict(item))

    df_new=df_new.assign(Consequent=Consequent)
        
    return df_new

# %% [markdown]
# # Analisi in frequenza delle regole per LEFT

# %%
df_left
# Out:
#      Consequent                                         Antecedent  Supp  \
# 591         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 599         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 607         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 614         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 622         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 629         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 636         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 642         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.05
# 650         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.08
# 664         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.09
# 657         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.08
# 677         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.08
# 683         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.08
# 798         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'sta...  0.05
# 805         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'sta...  0.05
# 670         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.09
# 812         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'sta...  0.05
# 818         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'sta...  0.05
# 689         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '3_T'...  0.09
# 694         Y_L    ('2_NP', 'insufficient_LE', 'medium_SL', '3_T')  0.09
# 702         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '0_S'...  0.05
# 709         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '0_S'...  0.05
# 825         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'N_W...  0.05
# 831         Y_L  ('2_NP', 'insufficient_LE', '3_T', '0_S', 'N_WA')  0.05
# 716         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '0_S'...  0.05
# 722         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', '0_S'...  0.05
# 849         Y_L  ('2_NP', 'insufficient_LE', '3_T', 'standard_H...  0.08
# 855         Y_L  ('2_NP', 'insufficient_LE', '3_T', 'standard_H...  0.08
# 837         Y_L   ('2_NP', 'insufficient_LE', '3_T', '0_S', 'N_P')  0.05
# 842         Y_L          ('2_NP', 'insufficient_LE', '3_T', '0_S')  0.05
# ...         ...                                                ...   ...
# 1025        Y_L  ('2_NP', 'medium_SL', '3_T', 'standard_H', 'N_...  0.10
# 1031        Y_L  ('2_NP', 'medium_SL', '3_T', 'standard_H', 'N_...  0.10
# 765         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', 'stan...  0.09
# 1001        Y_L  ('2_NP', 'medium_SL', '3_T', '0_S', 'N_WA', 'N...  0.06
# 1007        Y_L        ('2_NP', 'medium_SL', '3_T', '0_S', 'N_WA')  0.06
# 2436        Y_L  ('insufficient_LE', 'medium_SL', '3_T', '0_S',...  0.05
# 2442        Y_L  ('insufficient_LE', 'medium_SL', '3_T', '0_S',...  0.05
# 770         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', 'stan...  0.09
# 776         Y_L  ('2_NP', 'insufficient_LE', 'medium_SL', 'N_WA...  0.08
# 1018        Y_L                ('2_NP', 'medium_SL', '3_T', '0_S')  0.06
# 905         Y_L  ('2_NP', 'insufficient_LE', '0_S', 'standard_H...  0.05
# 910         Y_L   ('2_NP', 'insufficient_LE', '0_S', 'standard_H')  0.05
# 1037        Y_L  ('2_NP', 'medium_SL', '3_T', 'standard_H', 'N_P')  0.10
# 1042        Y_L         ('2_NP', 'medium_SL', '3_T', 'standard_H')  0.10
# 781         Y_L   ('2_NP', 'insufficient_LE', 'medium_SL', 'N_WA')  0.08
# 1013        Y_L         ('2_NP', 'medium_SL', '3_T', '0_S', 'N_P')  0.06
# 2448        Y_L  ('insufficient_LE', 'medium_SL', '3_T', '0_S',...  0.05
# 2453        Y_L     ('insufficient_LE', 'medium_SL', '3_T', '0_S')  0.05
# 786         Y_L    ('2_NP', 'insufficient_LE', 'medium_SL', 'N_P')  0.09
# 790         Y_L           ('2_NP', 'insufficient_LE', 'medium_SL')  0.09
# 1155        Y_L       ('2_NP', '3_T', '0_S', 'standard_H', 'N_WA')  0.06
# 916         Y_L  ('2_NP', 'insufficient_LE', '0_S', 'N_WA', 'N_P')  0.05
# 921         Y_L         ('2_NP', 'insufficient_LE', '0_S', 'N_WA')  0.05
# 1048        Y_L        ('2_NP', 'medium_SL', '3_T', 'N_WA', 'N_P')  0.10
# 1053        Y_L               ('2_NP', 'medium_SL', '3_T', 'N_WA')  0.10
# 1149        Y_L  ('2_NP', '3_T', '0_S', 'standard_H', 'N_WA', '...  0.06
# 2460        Y_L  ('insufficient_LE', 'medium_SL', '3_T', 'stand...  0.08
# 936         Y_L  ('2_NP', 'insufficient_LE', 'standard_H', 'N_W...  0.08
# 941         Y_L  ('2_NP', 'insufficient_LE', 'standard_H', 'N_WA')  0.08
# 1166        Y_L               ('2_NP', '3_T', '0_S', 'standard_H')  0.06
#
#       Conf  Lift
# 591   0.98  4.10
# 599   0.98  4.10
# 607   0.98  4.10
# 614   0.98  4.10
# 622   0.98  4.10
# 629   0.98  4.10
# 636   0.97  4.09
# 642   0.97  4.09
# 650   0.97  4.06
# 664   0.96  4.05
# 657   0.96  4.05
# 677   0.96  4.05
# 683   0.96  4.05
# 798   0.96  4.05
# 805   0.96  4.05
# 670   0.96  4.04
# 812   0.96  4.04
# 818   0.96  4.04
# 689   0.96  4.02
# 694   0.96  4.02
# 702   0.96  4.02
# 709   0.96  4.02
# 825   0.96  4.02
# 831   0.96  4.02
# 716   0.95  4.01
# 722   0.95  4.01
# 849   0.95  4.00
# 855   0.95  4.00
# 837   0.95  4.00
# 842   0.95  4.00
# ...    ...   ...
# 1025  0.93  3.91
# 1031  0.93  3.91
# 765   0.93  3.91
# 1001  0.93  3.91
# 1007  0.93  3.91
# 2436  0.93  3.91
# 2442  0.93  3.91
# 770   0.93  3.90
# 776   0.92  3.89
# 1018  0.93  3.89
# 905   0.93  3.89
# 910   0.93  3.89
# 1037  0.92  3.88
# 1042  0.92  3.88
# 781   0.92  3.88
# 1013  0.92  3.88
# 2448  0.92  3.86
# 2453  0.92  3.86
# 786   0.92  3.85
# 790   0.91  3.84
# 1155  0.91  3.84
# 916   0.92  3.84
# 921   0.92  3.84
# 1048  0.91  3.83
# 1053  0.91  3.83
# 1149  0.91  3.83
# 2460  0.91  3.82
# 936   0.91  3.81
# 941   0.91  3.80
# 1166  0.91  3.80
#
# [82 rows x 5 columns]

# %%
# converto in dizionario 
df_left_dict = df2df_dict(df_left)
df_left_dict.head()
# Out:
#      Supp  Conf  Lift                                         Antecedent  \
# 591  0.05  0.98   4.1  {u'Salary': u'0', u'Satisfaction_Level': u'med...
# 599  0.05  0.98   4.1  {u'Salary': u'0', u'Satisfaction_Level': u'med...
# 607  0.05  0.98   4.1  {u'Salary': u'0', u'Satisfaction_Level': u'med...
# 614  0.05  0.98   4.1  {u'Salary': u'0', u'Satisfaction_Level': u'med...
# 622  0.05  0.98   4.1  {u'Salary': u'0', u'Satisfaction_Level': u'med...
#
#           Consequent
# 591  {u'Left': u'Y'}
# 599  {u'Left': u'Y'}
# 607  {u'Left': u'Y'}
# 614  {u'Left': u'Y'}
# 622  {u'Left': u'Y'}

# %%
dict_values = extract_values(df_left_dict)
dict_values.keys()
# Out:
# ['Salary',
#  'Satisfaction_Level',
#  'Last_Evaluation',
#  'Work_Accident',
#  'Number_Projects',
#  'Department',
#  'Average_Montly_Hours',
#  'Promotion_Last_5_Years',
#  'Time_Spend_Company',
#  'Left']

# %%
lista_items=[]
lista_counts=[]

for variable in dict_values.keys():

    print(variable)
    #lista valori associata alla variabile
    lista_values = (dict_values[variable])
    #print(lista_values)

    if (len(lista_values)==0):
        break
    
    # estraggo i valori unici:n
    uniques = [lista_values[0]] #inizializzo col primo valore
    for value in lista_values:
        if(value not in uniques):
            uniques.append(value)
    # conto i valori per ciascun item unico
    uniques_counts=[]
    for i,unique in enumerate(uniques):
        uniques_counts.append(0)
        for value in lista_values:
            if (value ==unique) :
                uniques_counts[i]+=1

    # definisco gli items e li aggiungo alla lista complessiva
    for unique in uniques:
        lista_items.append("{} : {}".format(variable,unique))

    # aggiungo i counts alla lista complessiva    
    lista_counts=lista_counts+uniques_counts

#uniques_counts
#uniques
lista_items
lista_counts
# Out:
# Salary
# Satisfaction_Level
# Last_Evaluation
# Work_Accident
# Number_Projects
# Department
# [49, 55, 65, 45, 73]

# %%
lista_items
# Out:
# ['Salary : 0',
#  'Satisfaction_Level : medium',
#  'Last_Evaluation : insufficient',
#  'Work_Accident : N',
#  'Number_Projects : 2']

# %%
fig = plt.figure(figsize=(10,5))

x=lista_items
y= lista_counts
#y=np.array(lista_counts)/max(np.array(lista_counts))
plt.barh(x,y)
plt.ylabel('Antecedent Items')
plt.xlabel('Number of Rules')
plt.title('Rules for Employees who Left CAMBIARE SALARY VALUE')
plt.tight_layout()
plt.savefig("../../images/rules/rules_left.pdf")

# %%
prova= np.array(lista_counts)/max(np.array(lista_counts))
#max(prova)
prova
# Out:
# array([0, 0, 1, 0, 1])
