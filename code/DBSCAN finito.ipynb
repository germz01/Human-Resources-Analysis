# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math

# %% [markdown]
# # Data pre-processing

# %%
df = pd.read_csv('df_formatted.csv')
df.dtypes

df_num = df[['Satisfaction_Level','Last_Evaluation',
            'Average_Montly_Hours',
             'Time_Spend_Company','Number_Projects']]
df_num.dtypes
# Out:
# Satisfaction_Level      float64
# Last_Evaluation         float64
# Average_Montly_Hours      int64
# Time_Spend_Company        int64
# Number_Projects           int64
# dtype: object

# %% [markdown]
# ## Data standardization

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(copy=True, feature_range=(0, 1))

scaler.fit(df['Number_Projects'].values.reshape(-1, 1))
df_num['Number_Projects'] = scaler.transform(df_num['Number_Projects'].values.
                                        reshape(-1, 1))
scaler.fit(df['Average_Montly_Hours'].values.reshape(-1, 1))
df_num['Average_Montly_Hours'] = scaler.transform(df_num['Average_Montly_Hours'].
                                              values.reshape(-1, 1))
scaler.fit(df['Time_Spend_Company'].values.reshape(-1, 1))
df_num['Time_Spend_Company'] = scaler.transform(df_num['Time_Spend_Company'].values.
                                            reshape(-1, 1))
df_num['Average_Montly_Hours'] = [round(i, 2) for i in df_num['Average_Montly_Hours']]
df_num['Time_Spend_Company'] = [round(i, 2) for i in df_num['Time_Spend_Company']]
# Out:
# /home/maria/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/maria/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/maria/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/maria/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/maria/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df_num.head()
# Out:
#    Satisfaction_Level  Last_Evaluation  Average_Montly_Hours  \
# 0                0.38             0.53                  0.29
# 1                0.80             0.86                  0.78
# 2                0.11             0.88                  0.82
# 3                0.72             0.87                  0.59
# 4                0.37             0.52                  0.29
#
#    Time_Spend_Company  Number_Projects
# 0                0.13              0.0
# 1                0.50              0.6
# 2                0.25              1.0
# 3                0.38              0.6
# 4                0.13              0.0

# %% [markdown]
# ## Scelta di un intervallo per eps e MinPts tramite k-NN

# %%
from sklearn.neighbors import NearestNeighbors

# grafico k-nearest-neighbors
plt.close()
plt.figure(figsize=(12,6))

# k =  numero di vicinik = 4

for k in range(3,20,1): 
#for k in [3,5,7,10,100]:

    # applico l'algoritmo k-NN con distanza euclidea e k-MinPts
    nbrs = NearestNeighbors(n_neighbors=k, metric='minkowski', p=2).fit(df_num.values) 

    # estraggo la matrice delle distanze, ogni colonna rappresenta le distanze dal k-esimo vicino
    # l'ultima colonna è dunque la distanza che ci interessa
    Mdistances = nbrs.kneighbors(df_num.values)[0]


    df_kdist = pd.DataFrame(Mdistances) # converto la matrice delle distanze in DataFrame
    df_kdist.columns = [str(i) for i in range(1,k+1)] #rinomino le colonne
    df_kdist = df_kdist.sort_values(str(k)) # metto in ordine di distanza
    kdist = df_kdist[str(k)] # seleziono massima distanza tra i k-vicini

    x=np.arange(1,15000,1)
    y= kdist

    plt.plot(x,y)
    plt.title('Nearest Neighbors')
    plt.ylabel('k-distances for k nearest neighbors')
    plt.xlabel('Data objects sorted by k-distances')
    plt.legend(loc=2)
    plt.tight_layout()

# linee orizzontali per intervallo eps    
lista_h = [0.15,0.25]
for h in lista_h:
    plt.annotate(str(h),xy=(10000,h*1.1))
    plt.axhline(h)


plt.grid()
plt.savefig('nearestneighbors.pdf')

# %% [markdown]
# # Prove totali DBSCAN

# %%
from sklearn import metrics
from sklearn.cluster import DBSCAN

eps = []
sil = []
num_cl = []
range_MinPts = range(3,20,1)
range_eps = np.linspace(0.15,0.25,10) 
for e in range_eps:
    for num in range_MinPts:
        db = DBSCAN(eps=e, min_samples=num,metric='euclidean',
                         algorithm='auto',n_jobs=-1).fit(df_num)
        labels = db.labels_

        # Number of clusters in labels, ignoring noise if present.
        n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
        silhouette = metrics.silhouette_score(df_num, labels)
        if(n_clusters_ < 10):
            print ('con eps = %f e min samples %d' % (e,num))
            print('Estimated number of clusters: %d' % n_clusters_)
            print("Silhouette Coefficient: %0.3f"
              % metrics.silhouette_score(df_num, labels))
            eps.append(e)
            num_cl.append(n_clusters_)
            sil.append(metrics.silhouette_score(df_num, labels))
# Out:
# con eps = 0.150000 e min samples 14
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.075
# con eps = 0.150000 e min samples 16
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.099
# con eps = 0.150000 e min samples 17
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.096
# con eps = 0.150000 e min samples 18
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.093
# con eps = 0.150000 e min samples 19
# Estimated number of clusters: 8
# Silhouette Coefficient: 0.099
# con eps = 0.161111 e min samples 19
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.103
# con eps = 0.172222 e min samples 13
# Estimated number of clusters: 8
# Silhouette Coefficient: 0.067
# con eps = 0.172222 e min samples 14
# Estimated number of clusters: 8
# Silhouette Coefficient: 0.081
# con eps = 0.172222 e min samples 15
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.068
# con eps = 0.172222 e min samples 16
# Estimated number of clusters: 8
# Silhouette Coefficient: 0.078
# con eps = 0.172222 e min samples 17
# Estimated number of clusters: 8
# Silhouette Coefficient: 0.083
# con eps = 0.183333 e min samples 15
# Estimated number of clusters: 8
# Silhouette Coefficient: 0.081
# con eps = 0.183333 e min samples 16
# Estimated number of clusters: 8
# Silhouette Coefficient: 0.082
# con eps = 0.183333 e min samples 17
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.076
# con eps = 0.183333 e min samples 18
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.076
# con eps = 0.183333 e min samples 19
# Estimated number of clusters: 7
# Silhouette Coefficient: 0.096
# con eps = 0.194444 e min samples 10
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.085
# con eps = 0.194444 e min samples 18
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.067
# con eps = 0.194444 e min samples 19
# Estimated number of clusters: 8
# Silhouette Coefficient: 0.081
# con eps = 0.205556 e min samples 5
# Estimated number of clusters: 4
# Silhouette Coefficient: 0.299
# con eps = 0.205556 e min samples 6
# Estimated number of clusters: 5
# Silhouette Coefficient: 0.153
# con eps = 0.205556 e min samples 7
# Estimated number of clusters: 5
# Silhouette Coefficient: 0.290
# con eps = 0.205556 e min samples 8
# Estimated number of clusters: 5
# Silhouette Coefficient: 0.288
# con eps = 0.205556 e min samples 9
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.309
# con eps = 0.205556 e min samples 10
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.305
# con eps = 0.205556 e min samples 11
# Estimated number of clusters: 5
# Silhouette Coefficient: 0.146
# con eps = 0.205556 e min samples 12
# Estimated number of clusters: 5
# Silhouette Coefficient: 0.201
# con eps = 0.205556 e min samples 13
# Estimated number of clusters: 5
# Silhouette Coefficient: 0.122
# con eps = 0.205556 e min samples 14
# Estimated number of clusters: 4
# Silhouette Coefficient: 0.187
# con eps = 0.205556 e min samples 15
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.281
# con eps = 0.205556 e min samples 16
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.277
# con eps = 0.205556 e min samples 17
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.273
# con eps = 0.205556 e min samples 18
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.270
# con eps = 0.205556 e min samples 19
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.265
# con eps = 0.216667 e min samples 3
# Estimated number of clusters: 9
# Silhouette Coefficient: 0.106
# con eps = 0.216667 e min samples 4
# Estimated number of clusters: 7
# Silhouette Coefficient: 0.130
# con eps = 0.216667 e min samples 5
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.322
# con eps = 0.216667 e min samples 6
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.320
# con eps = 0.216667 e min samples 7
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.330
# con eps = 0.216667 e min samples 8
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.326
# con eps = 0.216667 e min samples 9
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.330
# con eps = 0.216667 e min samples 10
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.328
# con eps = 0.216667 e min samples 11
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.307
# con eps = 0.216667 e min samples 12
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.305
# con eps = 0.216667 e min samples 13
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.300
# con eps = 0.216667 e min samples 14
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.292
# con eps = 0.216667 e min samples 15
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.304
# con eps = 0.216667 e min samples 16
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.298
# con eps = 0.216667 e min samples 17
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.305
# con eps = 0.216667 e min samples 18
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.298
# con eps = 0.216667 e min samples 19
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.294
# con eps = 0.227778 e min samples 3
# Estimated number of clusters: 6
# Silhouette Coefficient: 0.132
# con eps = 0.227778 e min samples 4
# Estimated number of clusters: 5
# Silhouette Coefficient: 0.175
# con eps = 0.227778 e min samples 5
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.325
# con eps = 0.227778 e min samples 6
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.325
# con eps = 0.227778 e min samples 7
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.333
# con eps = 0.227778 e min samples 8
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.333
# con eps = 0.227778 e min samples 9
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.337
# con eps = 0.227778 e min samples 10
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.336
# con eps = 0.227778 e min samples 11
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.334
# con eps = 0.227778 e min samples 12
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.334
# con eps = 0.227778 e min samples 13
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.310
# con eps = 0.227778 e min samples 14
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.308
# con eps = 0.227778 e min samples 15
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.332
# con eps = 0.227778 e min samples 16
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.329
# con eps = 0.227778 e min samples 17
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.324
# con eps = 0.227778 e min samples 18
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.316
# con eps = 0.227778 e min samples 19
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.302
# con eps = 0.238889 e min samples 3
# Estimated number of clusters: 4
# Silhouette Coefficient: 0.248
# con eps = 0.238889 e min samples 4
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.328
# con eps = 0.238889 e min samples 5
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.328
# con eps = 0.238889 e min samples 6
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.328
# con eps = 0.238889 e min samples 7
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.337
# con eps = 0.238889 e min samples 8
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.337
# con eps = 0.238889 e min samples 9
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.338
# con eps = 0.238889 e min samples 10
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.338
# con eps = 0.238889 e min samples 11
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.337
# con eps = 0.238889 e min samples 12
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.336
# con eps = 0.238889 e min samples 13
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.340
# con eps = 0.238889 e min samples 14
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.340
# con eps = 0.238889 e min samples 15
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.339
# con eps = 0.238889 e min samples 16
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.337
# con eps = 0.238889 e min samples 17
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.313
# con eps = 0.238889 e min samples 18
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.313
# con eps = 0.238889 e min samples 19
# Estimated number of clusters: 4
# Silhouette Coefficient: 0.309
# con eps = 0.250000 e min samples 3
# Estimated number of clusters: 4
# Silhouette Coefficient: 0.316
# con eps = 0.250000 e min samples 4
# Estimated number of clusters: 4
# Silhouette Coefficient: 0.316
# con eps = 0.250000 e min samples 5
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.331
# con eps = 0.250000 e min samples 6
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.331
# con eps = 0.250000 e min samples 7
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.342
# con eps = 0.250000 e min samples 8
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.342
# con eps = 0.250000 e min samples 9
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.342
# con eps = 0.250000 e min samples 10
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.342
# con eps = 0.250000 e min samples 11
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.342
# con eps = 0.250000 e min samples 12
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.342
# con eps = 0.250000 e min samples 13
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.344
# con eps = 0.250000 e min samples 14
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.344
# con eps = 0.250000 e min samples 15
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.344
# con eps = 0.250000 e min samples 16
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.343
# con eps = 0.250000 e min samples 17
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.345
# con eps = 0.250000 e min samples 18
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.343
# con eps = 0.250000 e min samples 19
# Estimated number of clusters: 2
# Silhouette Coefficient: 0.343

# %% [markdown]
# ## Assegnazione cluster

# %%
from sklearn import metrics
from sklearn.cluster import DBSCAN

db = DBSCAN(eps=0.227778, min_samples=13,metric='euclidean',
                 algorithm='auto',n_jobs=-1).fit(df_num)
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print ('con eps = 0.22 e min samples 15' )
print('Estimated number of clusters: %d' % n_clusters_)
print("Silhouette Coefficient: %0.3f"
  % metrics.silhouette_score(df_num, labels))
# Out:
# con eps = 0.22 e min samples 15
# Estimated number of clusters: 3
# Silhouette Coefficient: 0.310

# %%
df_num['cluster'] = labels
# Out:
# /home/maria/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_num
# Out:
#        Satisfaction_Level  Last_Evaluation  Average_Montly_Hours  \
# 0                    0.38             0.53                  0.29
# 1                    0.80             0.86                  0.78
# 2                    0.11             0.88                  0.82
# 3                    0.72             0.87                  0.59
# 4                    0.37             0.52                  0.29
# 5                    0.41             0.50                  0.27
# 6                    0.10             0.77                  0.71
# 7                    0.92             0.85                  0.76
# 8                    0.89             1.00                  0.60
# 9                    0.42             0.53                  0.21
# 10                   0.45             0.54                  0.18
# 11                   0.11             0.81                  0.98
# 12                   0.84             0.92                  0.64
# 13                   0.41             0.55                  0.24
# 14                   0.36             0.56                  0.19
# 15                   0.38             0.54                  0.22
# 16                   0.45             0.47                  0.30
# 17                   0.78             0.99                  0.74
# 18                   0.45             0.51                  0.30
# 19                   0.76             0.89                  0.78
# 20                   0.11             0.83                  0.87
# 21                   0.38             0.55                  0.24
# 22                   0.09             0.95                  0.97
# 23                   0.46             0.57                  0.20
# 24                   0.40             0.53                  0.29
# 25                   0.89             0.92                  0.68
# 26                   0.82             0.87                  0.67
# 27                   0.40             0.49                  0.18
# 28                   0.41             0.46                  0.15
# 29                   0.38             0.50                  0.17
# ...                   ...              ...                   ...
# 14969                0.43             0.46                  0.29
# 14970                0.78             0.93                  0.60
# 14971                0.39             0.45                  0.21
# 14972                0.11             0.97                  1.00
# 14973                0.36             0.52                  0.22
# 14974                0.36             0.54                  0.27
# 14975                0.10             0.79                  1.00
# 14976                0.40             0.47                  0.19
# 14977                0.81             0.85                  0.72
# 14978                0.40             0.47                  0.22
# 14979                0.09             0.93                  0.93
# 14980                0.76             0.89                  0.66
# 14981                0.73             0.93                  0.31
# 14982                0.38             0.49                  0.19
# 14983                0.72             0.84                  0.75
# 14984                0.40             0.56                  0.24
# 14985                0.91             0.99                  0.74
# 14986                0.85             0.85                  0.71
# 14987                0.90             0.70                  0.51
# 14988                0.46             0.55                  0.23
# 14989                0.43             0.57                  0.29
# 14990                0.89             0.88                  0.62
# 14991                0.09             0.81                  0.75
# 14992                0.40             0.48                  0.28
# 14993                0.76             0.83                  0.92
# 14994                0.40             0.57                  0.26
# 14995                0.37             0.48                  0.30
# 14996                0.37             0.53                  0.22
# 14997                0.11             0.96                  0.86
# 14998                0.37             0.52                  0.29
#
#        Time_Spend_Company  Number_Projects  cluster
# 0                    0.13              0.0        0
# 1                    0.50              0.6        0
# 2                    0.25              1.0        0
# 3                    0.38              0.6        0
# 4                    0.13              0.0        0
# 5                    0.13              0.0        0
# 6                    0.25              0.8        0
# 7                    0.38              0.6        0
# 8                    0.38              0.6        0
# 9                    0.13              0.0        0
# 10                   0.13              0.0        0
# 11                   0.25              0.8        0
# 12                   0.38              0.4        0
# 13                   0.13              0.0        0
# 14                   0.13              0.0        0
# 15                   0.13              0.0        0
# 16                   0.13              0.0        0
# 17                   0.50              0.4        0
# 18                   0.13              0.0        0
# 19                   0.38              0.6        0
# 20                   0.25              0.8        0
# 21                   0.13              0.0        0
# 22                   0.25              0.8        0
# 23                   0.13              0.0        0
# 24                   0.13              0.0        0
# 25                   0.38              0.6        0
# 26                   0.38              0.4        0
# 27                   0.13              0.0        0
# 28                   0.13              0.0        0
# 29                   0.13              0.0        0
# ...                   ...              ...      ...
# 14969                0.13              0.0        0
# 14970                0.38              0.4        0
# 14971                0.13              0.0        0
# 14972                0.25              0.8        0
# 14973                0.13              0.0        0
# 14974                0.13              0.0        0
# 14975                0.25              1.0        0
# 14976                0.13              0.0        0
# 14977                0.50              0.4        0
# 14978                0.13              0.0        0
# 14979                0.25              0.8        0
# 14980                0.38              0.6        0
# 14981                0.25              0.6        0
# 14982                0.13              0.0        0
# 14983                0.38              0.6        0
# 14984                0.13              0.0        0
# 14985                0.38              0.6        0
# 14986                0.50              0.4        0
# 14987                0.25              0.6        0
# 14988                0.13              0.0        0
# 14989                0.13              0.0        0
# 14990                0.38              0.6        0
# 14991                0.25              0.8        0
# 14992                0.13              0.0        0
# 14993                0.50              0.8        0
# 14994                0.13              0.0        0
# 14995                0.13              0.0        0
# 14996                0.13              0.0        0
# 14997                0.25              0.8        0
# 14998                0.13              0.0        0
#
# [14999 rows x 6 columns]

# %% [markdown]
# # Dati csv

# %%
df_num.groupby('cluster').describe().to_csv('dbscan.csv')
