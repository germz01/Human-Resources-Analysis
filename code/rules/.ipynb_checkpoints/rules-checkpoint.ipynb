# %% [markdown]
# Association rules

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Numero di regole in funzione di supp e conf

# %% [markdown]
# ## numero di regole per supp=20

# %%
supp=20
conf_range=np.arange(50,105,5)
Nrules_supp20 = []
for i,conf in enumerate(conf_range):
    df=pd.read_csv("../../data/rules/rules_supp{}_conf{}.csv".format(supp,conf))
    df=df.query('Lift>1')
    Nrules_supp20.append(df.shape[0])
Nrules_supp20
# Out:
# [122, 99, 85, 81, 69, 69, 61, 53, 37, 31, 8]

# %%
## numero di regole per supp=10

# %%
supp=10
conf_range=np.arange(50,105,5)
Nrules_supp10 = []
for i,conf in enumerate(conf_range):
    df=pd.read_csv("../../data/rules/rules_supp{}_conf{}.csv".format(supp,conf))
    df=df.query('Lift>1')
    Nrules_supp10.append(df.shape[0])
Nrules_supp10
# Out:
# [914, 781, 695, 656, 584, 579, 542, 508, 411, 337, 63]

# %%
## numero di regole per supp=5

# %%
supp=5
conf_range=np.arange(50,105,5)
Nrules_supp5 = []
for i,conf in enumerate(conf_range):
    df=pd.read_csv("../../data/rules/rules_supp{}_conf{}.csv".format(supp,conf))
    df=df.query('Lift>1')
    Nrules_supp5.append(df.shape[0])
Nrules_supp5
# Out:
# [4457, 3984, 3594, 3236, 3029, 2955, 2819, 2572, 2261, 1881, 261]

# %% [markdown]
# # Grafico numero di regole (Lift>1)

# %%
In [189]
###########################################################
SMALL_SIZE = 15
MEDIUM_SIZE = 20
BIGGER_SIZE = 30
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y label
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('axes', axisbelow=True)
###########################################################


fig = plt.figure(figsize=(13,5))
ax = fig.add_subplot(111)
plt.plot(conf_range,Nrules_supp20, label='MinSupp = 20%', linewidth=5)
plt.plot(conf_range,Nrules_supp10, label='MinSupp = 10%', linewidth=5)
plt.plot(conf_range,Nrules_supp5, label='MinSupp =  5%', linewidth=5)
plt.scatter(conf_range,Nrules_supp20,s=100)
plt.scatter(conf_range,Nrules_supp10,s=100)
plt.scatter(conf_range,Nrules_supp5,s=100)

plt.legend()

ax.set_yscale('log')

plt.xlabel('Minimum Confidence (%)')
plt.ylabel('Number of rules (logscale)')

plt.ylim(1,10000)

plt.grid(b=True, which='major', color='0', linestyle='--')
plt.grid(b=True, which='minor', color='0', linestyle=':')

plt.title("Number of association rules with Lift>1")
plt.tight_layout()

plt.savefig("../../images/rules/andamentonumero.pdf")

#ax.yaxis.set_major_locator(10)

# %%
###########################################################

SMALL_SIZE = 15
MEDIUM_SIZE = 20
BIGGER_SIZE = 30

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y label
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('axes', axisbelow=True)
###########################################################

# %%
# regole generali

# %%
df = pd.read_csv("../../data/rules/rules_supp20_conf50.csv")
df.shape
#df_filtered = df.query('Supp>0.2') # perchè non è maggiore di 20???
#df_filtered = df_filtered.query('Lift>1')
df_filtered=df
df_filtered.describe()
# Out:
#              Supp        Conf        Lift
# count  259.000000  259.000000  259.000000
# mean     0.289807    0.826911    1.112896
# std      0.102271    0.154743    0.271226
# min      0.200000    0.500000    0.880000
# 25%      0.220000    0.730000    0.990000
# 50%      0.260000    0.850000    1.000000
# 75%      0.320000    0.980000    1.125000
# max      0.840000    1.000000    2.100000

# %%
fig = plt.figure(figsize=(10,10))
plt.grid()
size= 5000*(df_filtered.Supp)**(2)
palette='Accent'
palette='viridis'
plt.scatter(x='Conf', y='Lift',data=df_filtered,s=size, alpha=0.7 ,c='Supp',cmap =plt.cm.get_cmap(palette,3))
cb = plt.colorbar(orientation='horizontal',extend='max',ticks=np.arange(0.20,0.70,0.10))
cb.set_label('Support')

#plt.colorbar(extend='both')
plt.clim(0.2,0.5)
plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.title("Interest of Association rules, for Min Supp = 20%")
#plt.legend()
plt.tight_layout()

plt.savefig("../../images/rules/rules_supp20.pdf")

# %%
# ?plt.colorbar()

# %%
df_interesting = df_filtered.query(" Lift >1.7")
df_interesting = df_interesting.sort_values(by=['Conf'],ascending=False)

import sys
stdout= sys.stdout
sys.stdout = open('../../data/rules/rules_supp20.txt','w')
print( df_interesting.to_latex(index=False) )
#print( df[100:300].to_latex(index=False) )
sys.stdout=stdout

#df.query(" Conf<0.7 & Lift >1.8")[0:1].to_latex(index_names=False) 

##?df.to_latex()
df_interesting
# Out:
#       Consequent                              Antecedent  Supp  Conf  Lift
# 55       high_SL  ('very good_LE', 'N_L', 'N_WA', 'N_P')  0.22  1.00  2.09
# 59       high_SL         ('very good_LE', 'N_L', 'N_WA')  0.23  1.00  2.09
# 63       high_SL          ('very good_LE', 'N_L', 'N_P')  0.27  1.00  2.09
# 66       high_SL                 ('very good_LE', 'N_L')  0.27  1.00  2.09
# 70       high_SL         ('very good_LE', 'N_WA', 'N_P')  0.27  1.00  2.09
# 73       high_SL                ('very good_LE', 'N_WA')  0.27  1.00  2.09
# 76       high_SL                 ('very good_LE', 'N_P')  0.31  1.00  2.09
# 78       high_SL                       ('very good_LE',)  0.32  1.00  2.09
# 71  very good_LE              ('high_SL', 'N_WA', 'N_P')  0.27  0.68  2.10
# 74  very good_LE                     ('high_SL', 'N_WA')  0.27  0.68  2.10
# 77  very good_LE                      ('high_SL', 'N_P')  0.31  0.67  2.09
# 79  very good_LE                            ('high_SL',)  0.32  0.67  2.09
# 56  very good_LE       ('high_SL', 'N_L', 'N_WA', 'N_P')  0.22  0.66  2.05
# 60  very good_LE              ('high_SL', 'N_L', 'N_WA')  0.23  0.66  2.06
# 64  very good_LE               ('high_SL', 'N_L', 'N_P')  0.27  0.66  2.05
# 67  very good_LE                      ('high_SL', 'N_L')  0.27  0.66  2.05

# %%
# Regole per supp=5

# %%
df = pd.read_csv("../../data/rules/rules_supp5_conf50.csv")
df.shape
#df_filtered = df.query('Supp>0.2') # perchè non è maggiore di 20???
#df_filtered = df_filtered.query('Lift>1')
df_filtered=df
df_filtered.describe()
# Out:
#               Supp         Conf         Lift
# count  5862.000000  5862.000000  5862.000000
# mean      0.088763     0.835553     1.658640
# std       0.056477     0.164999     1.118199
# min       0.050000     0.500000     0.660000
# 25%       0.060000     0.690000     1.010000
# 50%       0.070000     0.880000     1.140000
# 75%       0.100000     0.980000     2.030000
# max       0.840000     1.000000     7.170000

# %%
plt.close()
fig = plt.figure(figsize=(10,10))
plt.grid()
size= 2000*(df_filtered.Supp)**(1)
plt.scatter(x='Conf', y='Lift',data=df_filtered,s=size, alpha=0.7 ,c='Supp',cmap =plt.cm.get_cmap('Accent',3))

plt.clim(0.05,0.2)
cb = plt.colorbar(extend='max',orientation='horizontal',ticks=np.arange(0.05,0.70,0.05))
cb.set_label('Support')


plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.title("Interest of Association rules, for Min Supp = 5%")
#plt.legend()
plt.tight_layout()

plt.savefig("../../images/rules/rules_supp5.pdf")

# %%
df_interesting = df_filtered.query(" Lift >5")
df_interesting = df_interesting.query(" Conf >0.95")
df_interesting = df_interesting.sort_values(by=['Consequent','Lift','Supp'],ascending=False)
df_interesting
((df_interesting.Antecedent[665]))
# Out:
# "('Y_L', 'insufficient_LE', 'medium_SL', '3_T', 'standard_H', 'N_P')"

# %%
import sys
stdout= sys.stdout
sys.stdout = open('../../data/rules/rules_supp5.txt','w')
print( df_interesting.to_latex(index=False) )
sys.stdout=stdout

##?df.to_latex()

# %%
df_left = df_filtered.query(" Consequent=='Y_L'")
df_left = df_left.query(" Conf >0.8")
df_left = df_left.sort_values(by=['Consequent','Supp','Lift'],ascending=False)
df_left.describe()
(df_left.iloc[1])
# Out:
# Consequent                                                  Y_L
# Antecedent    ('2_NP', 'medium_SL', '3_T', 'standard_H', 'N_...
# Supp                                                        0.1
# Conf                                                       0.93
# Lift                                                       3.91
# Name: 1031, dtype: object

# %%
df_left.head()
# Out:
#      Consequent                                         Antecedent  Supp  \
# 1025        Y_L  ('2_NP', 'medium_SL', '3_T', 'standard_H', 'N_...   0.1
# 1031        Y_L  ('2_NP', 'medium_SL', '3_T', 'standard_H', 'N_...   0.1
# 1037        Y_L  ('2_NP', 'medium_SL', '3_T', 'standard_H', 'N_P')   0.1
# 1042        Y_L         ('2_NP', 'medium_SL', '3_T', 'standard_H')   0.1
# 1048        Y_L        ('2_NP', 'medium_SL', '3_T', 'N_WA', 'N_P')   0.1
#
#       Conf  Lift
# 1025  0.93  3.91
# 1031  0.93  3.91
# 1037  0.92  3.88
# 1042  0.92  3.88
# 1048  0.91  3.83

# %%
variables = ['Time_Spend_Company',
            'Department',
            'Number_Projects',
            'Promotion_Last_5_Years',
            'Left',
            'Average_Montly_Hours',
            'Work_Accident',
            'Last_Evaluation',
            'Salary',
            'Satisfaction_Level']

other_columns = ['Antecedent','Consequent','Supp','Conf','Lift']

from copy import copy
columns = copy(variables)

for col in other_columns:
    columns.append(col)

df_empty = pd.DataFrame(columns=other_columns,index=np.arange(1))
df_empty.head()
# Out:
#   Antecedent Consequent Supp Conf Lift
# 0        NaN        NaN  NaN  NaN  NaN

# %%
var_dict = {
    'T':'Time_Spend_Company',
    'D':'Department',
    'NP':'Number_Projects',
    'P':'Promotion_Last_5_Years',
    'L':'Left',
    'H':'Average_Montly_Hours',
    'WA':'Work_Accident',
    'LE':'Last_Evaluation',
    'S':'Salary',
    'SL':'Satisfaction_Level'
}

def item2dict(item):
    ## splitto la stringa
    item_split = item.split('_')
    # definisco la lista variabile,valore
    item_list = {var_dict[item_split[1]] : item_split[0]}
    return item_list


item=df.Consequent[10]
item2dict(item)
# Out:
# {'Last_Evaluation': 'insufficient'}

# %%
# funzione che converte la parte antecedent in lista di dizionari

from ast import literal_eval

def antecedent2list(antecedent_str):
    antecedent_tuple = literal_eval(antecedent_str)

    out_list = []
    for item in antecedent_tuple:
        out_list.append(item2dict(item=item))
        
    return out_list

#esempio
out= antecedent2list(df.Antecedent[40])
out
# Out:
# [{'Number_Projects': '3'}, {'Left': 'N'}, {'Promotion_Last_5_Years': 'N'}]

# %%
def df2df_list(df):
    """funzione che converte 
    le stringhe relative alle regole in 
    liste di dizionari """

    df_new = df.copy()

    df_new = df_new.drop(['Antecedent','Consequent'],axis=1)

    Antecedent=[]
    for i,item in enumerate(df.Antecedent):
        Antecedent.append(antecedent2list(item))

    df_new=df_new.assign(Antecedent=Antecedent)

    Consequent=[]
    for i,item in enumerate(df.Consequent):
        Consequent.append(item2dict(item))

    df_new=df_new.assign(Consequent=Consequent)
        
    return df_new        

prova = df2df_list(df)
prova.head()
# Out:
#    Supp  Conf  Lift                                         Antecedent  \
# 0  0.17  0.83  0.97  [{u'Time_Spend_Company': u'2'}, {u'Left': u'N'...
# 1  0.18  0.83  0.96   [{u'Time_Spend_Company': u'2'}, {u'Left': u'N'}]
# 2  0.21  0.98  1.00   [{u'Time_Spend_Company': u'2'}, {u'Left': u'N'}]
# 3  0.21  0.98  1.29  [{u'Time_Spend_Company': u'2'}, {u'Promotion_L...
# 4  0.21  0.98  1.29                    [{u'Time_Spend_Company': u'2'}]
#
#                           Consequent
# 0           {u'Work_Accident': u'N'}
# 1           {u'Work_Accident': u'N'}
# 2  {u'Promotion_Last_5_Years': u'N'}
# 3                    {u'Left': u'N'}
# 4                    {u'Left': u'N'}

# %% [markdown]
# ## Analisi regole

# %%
df_selected = df.query(" Conf>0.9 & Lift >1.7")
df_selected
df_selected_list = df2df_list(df_selected)

# %%
df = pd.read_csv("../../data/rules_supp5_conf60.csv")
df.shape
df_filtered = df.query('Supp>0.05') # perchè non è maggiore di 20???
df_filtered = df_filtered.query('Lift>1')
df_filtered = df_filtered.query('Conf>0.8')
df_filtered.describe()
# Out:
#               Supp         Conf         Lift
# count  2163.000000  2163.000000  2163.000000
# mean      0.090490     0.952247     1.918618
# std       0.039957     0.053489     1.273471
# min       0.060000     0.810000     1.010000
# 25%       0.060000     0.920000     1.030000
# 50%       0.080000     0.980000     1.290000
# 75%       0.100000     0.990000     2.270000
# max       0.480000     1.000000     6.840000

# %%
fig = plt.figure(figsize=(13,5))
plt.grid()
#size= 10000*(df_filtered.Supp)**(2)
size=300
plt.scatter(x='Conf', y='Lift',data=df_filtered,s=size, alpha=0.4 ,c='Supp',cmap =plt.cm.get_cmap('viridis',3))
#plt.colorbar()
plt.colorbar(extend='both')
plt.clim(0.05,0.2)
plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.title("Association rules, for Min Supp = 5% and Lift>1")
#plt.legend()
plt.savefig("../../images/rules/rules_supp5.pdf")

# %%
df_filtered = df_filtered.query('Lift>5')
df_filtered= df_filtered.sort_values(by=['Lift'],ascending=False)
df_filtered.describe()
print(df_filtered)

df_filtered.to_csv('rules_filtered.csv')
# Out:
#      Consequent                                         Antecedent  Supp  \
# 342      low_SL          ('4_T', 'insufficient_LE', 'N_WA', 'N_P')  0.07
# 350      low_SL                         ('4_T', 'insufficient_LE')  0.07
# 345      low_SL                 ('4_T', 'insufficient_LE', 'N_WA')  0.07
# 348      low_SL                  ('4_T', 'insufficient_LE', 'N_P')  0.07
# 78       low_SL                        ('6_NP', 'insufficient_LE')  0.06
# 76       low_SL                 ('6_NP', 'insufficient_LE', 'N_P')  0.06
# 434      low_SL         ('insufficient_LE', 'intensive_H', 'N_WA')  0.08
# 430      low_SL  ('insufficient_LE', 'intensive_H', 'N_WA', 'N_P')  0.08
# 441      low_SL                 ('insufficient_LE', 'intensive_H')  0.09
# 438      low_SL          ('insufficient_LE', 'intensive_H', 'N_P')  0.09
# 882        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.08
# 889        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.09
# 895        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.09
# 875        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.08
# 1259       2_NP          ('Y_L', 'medium_SL', '3_T', 'standard_H')  0.10
# 1254       2_NP   ('Y_L', 'medium_SL', '3_T', 'standard_H', 'N_P')  0.10
# 902        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.08
# 1191       2_NP  ('Y_L', 'medium_SL', '3_T', '0_S', 'standard_H...  0.06
# 919        2_NP     ('Y_L', 'insufficient_LE', 'medium_SL', '3_T')  0.09
# 908        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.08
# 1211       2_NP   ('Y_L', 'medium_SL', '3_T', '0_S', 'standard_H')  0.06
# 1242       2_NP  ('Y_L', 'medium_SL', '3_T', 'standard_H', 'N_W...  0.10
# 914        2_NP  ('Y_L', 'insufficient_LE', 'medium_SL', '3_T',...  0.09
# 1248       2_NP  ('Y_L', 'medium_SL', '3_T', 'standard_H', 'N_WA')  0.10
# 1205       2_NP  ('Y_L', 'medium_SL', '3_T', '0_S', 'standard_H...  0.06
# 1198       2_NP  ('Y_L', 'medium_SL', '3_T', '0_S', 'standard_H...  0.06
# 1080       2_NP  ('Y_L', 'insufficient_LE', '3_T', 'standard_H'...  0.08
# 1091       2_NP    ('Y_L', 'insufficient_LE', '3_T', 'standard_H')  0.09
# 1086       2_NP  ('Y_L', 'insufficient_LE', '3_T', 'standard_H'...  0.09
# 1074       2_NP  ('Y_L', 'insufficient_LE', '3_T', 'standard_H'...  0.08
# ...         ...                                                ...   ...
# 1482       2_NP               ('Y_L', 'standard_H', 'N_WA', 'N_P')  0.10
# 1490       2_NP                       ('Y_L', 'standard_H', 'N_P')  0.10
# 1486       2_NP                      ('Y_L', 'standard_H', 'N_WA')  0.10
# 1493       2_NP                              ('Y_L', 'standard_H')  0.10
# 1451       2_NP        ('Y_L', '0_S', 'standard_H', 'N_WA', 'N_P')  0.06
# 1583       2_NP  ('insufficient_LE', 'medium_SL', '3_T', 'N_WA'...  0.08
# 1461       2_NP                ('Y_L', '0_S', 'standard_H', 'N_P')  0.06
# 1456       2_NP               ('Y_L', '0_S', 'standard_H', 'N_WA')  0.06
# 1465       2_NP                       ('Y_L', '0_S', 'standard_H')  0.06
# 1588       2_NP    ('insufficient_LE', 'medium_SL', '3_T', 'N_WA')  0.09
# 1593       2_NP     ('insufficient_LE', 'medium_SL', '3_T', 'N_P')  0.09
# 1597       2_NP            ('insufficient_LE', 'medium_SL', '3_T')  0.09
# 1698       2_NP    ('insufficient_LE', '3_T', '0_S', 'standard_H')  0.06
# 1724       2_NP  ('insufficient_LE', '3_T', 'standard_H', 'N_WA...  0.09
# 1729       2_NP   ('insufficient_LE', '3_T', 'standard_H', 'N_WA')  0.09
# 1734       2_NP    ('insufficient_LE', '3_T', 'standard_H', 'N_P')  0.09
# 1738       2_NP           ('insufficient_LE', '3_T', 'standard_H')  0.09
# 1620       2_NP  ('insufficient_LE', 'medium_SL', '0_S', 'stand...  0.06
# 1616       2_NP  ('insufficient_LE', 'medium_SL', '0_S', 'stand...  0.06
# 1644       2_NP  ('insufficient_LE', 'medium_SL', 'standard_H',...  0.09
# 1649       2_NP  ('insufficient_LE', 'medium_SL', 'standard_H',...  0.09
# 1714       2_NP           ('insufficient_LE', '3_T', '0_S', 'N_P')  0.06
# 1718       2_NP                  ('insufficient_LE', '3_T', '0_S')  0.06
# 1654       2_NP  ('insufficient_LE', 'medium_SL', 'standard_H',...  0.09
# 1658       2_NP     ('insufficient_LE', 'medium_SL', 'standard_H')  0.09
# 1743       2_NP          ('insufficient_LE', '3_T', 'N_WA', 'N_P')  0.09
# 1747       2_NP                 ('insufficient_LE', '3_T', 'N_WA')  0.09
# 1638       2_NP            ('insufficient_LE', 'medium_SL', '0_S')  0.06
# 1635       2_NP     ('insufficient_LE', 'medium_SL', '0_S', 'N_P')  0.06
# 1751       2_NP                  ('insufficient_LE', '3_T', 'N_P')  0.09
#
#       Conf  Lift
# 342   0.93  6.84
# 350   0.93  6.84
# 345   0.93  6.84
# 348   0.93  6.83
# 78    0.93  6.78
# 76    0.93  6.78
# 434   0.90  6.59
# 430   0.90  6.59
# 441   0.90  6.55
# 438   0.89  6.54
# 882   1.00  6.28
# 889   1.00  6.28
# 895   1.00  6.28
# 875   1.00  6.28
# 1259  1.00  6.26
# 1254  1.00  6.26
# 902   0.99  6.25
# 1191  1.00  6.25
# 919   0.99  6.25
# 908   0.99  6.25
# 1211  1.00  6.25
# 1242  1.00  6.25
# 914   0.99  6.25
# 1248  1.00  6.25
# 1205  1.00  6.25
# 1198  1.00  6.25
# 1080  0.99  6.23
# 1091  0.99  6.23
# 1086  0.99  6.23
# 1074  0.99  6.23
# ...    ...   ...
# 1482  0.93  5.83
# 1490  0.93  5.83
# 1486  0.93  5.82
# 1493  0.93  5.82
# 1451  0.92  5.80
# 1583  0.92  5.79
# 1461  0.92  5.79
# 1456  0.92  5.78
# 1465  0.92  5.77
# 1588  0.92  5.77
# 1593  0.91  5.74
# 1597  0.91  5.72
# 1698  0.90  5.62
# 1724  0.89  5.60
# 1729  0.89  5.57
# 1734  0.87  5.48
# 1738  0.87  5.46
# 1620  0.87  5.45
# 1616  0.87  5.44
# 1644  0.85  5.34
# 1649  0.85  5.32
# 1714  0.84  5.25
# 1718  0.84  5.25
# 1654  0.83  5.23
# 1658  0.83  5.21
# 1743  0.82  5.18
# 1747  0.82  5.16
# 1638  0.82  5.16
# 1635  0.82  5.15
# 1751  0.81  5.06
#
# [120 rows x 5 columns]

# %%
df_filtered.query('(Consequent=="Y_L") or ("Y_L" in Antecedent) ').head(100)

#df_rules.query('(Consequent=="Y_L") or ("Y_L" in Antecedent) ').sort_values(by=['Supp'],ascending=False)
# Out:
# Empty DataFrame
# Columns: [Consequent, Antecedent, Supp, Conf, Lift]
# Index: []

# %%
df_rules.query('(Consequent=="Y_L") ').
df_rules.query('(Consequent=="Y_L") & (Lift>1) ').shape
df_rules.query('(Consequent=="Y_L") & (Lift>4) ')
df_rules.head(50).shape
df_rules.to_csv("prova.csv")





df_rules.shape
# Out:
#   File "<ipython-input-52-0c9513da143a>", line 1
#     df_rules.query('(Consequent=="Y_L") ').
#                                            ^
# SyntaxError: invalid syntax

# %%
from fim import apriori
# ?apriori
